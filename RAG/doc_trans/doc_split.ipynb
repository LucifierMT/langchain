# %% [markdown]
# ### 文档切割
# - 将文档分成笑的，有意义的块
# - 将小的块组合成一个更大的块，直到达到一定的大小
# - 一旦达到一定的大小，接着开始创建与下一个块重叠的部分

# %% [markdown]
# #### 示例
# - 文档切割
# - 按字符切割
# - 代码文档切割
# - 按token切割

# %%
# 文档切割

from langchain_text_splitters import RecursiveCharacterTextSplitter

# 读取文件
with open("novel.txt") as f:
    lingwujiyuan = f.read()

# 使用递归字符切分器
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=200,          # 每个块的大小
    chunk_overlap=50,        # 重叠的字符数
    length_function=len,      # 计算长度的函数
    add_start_index=True,     # 是否添加开始索引
)

text = text_splitter.create_documents([lingwujiyuan])
text
# Out:
# [Document(metadata={'start_index': 0}, page_content='《灵武纪元》\n\n第一章：废柴觉醒\n\n灵武大陆，万族林立，强者为尊。\n\n这片大陆上，灵气如海，孕育了无数修炼者。从低阶的灵砂境到巅峰的灵峰境，每一个境界都如同天堑，划分着凡人与神祇的界限。然而，在这片强者争锋的土地上，却有一个少年，被家族视为耻辱，连最基础的灵力都无法凝聚。\n\n他叫林澈，是林氏家族旁支的弃子。'),
#  Document(metadata={'start_index': 138}, page_content='他叫林澈，是林氏家族旁支的弃子。\n\n林氏家族，乃是北境灵武世家，以“灵焰剑道”闻名于世。家族子弟天赋卓绝，十岁便能引动灵力，十五岁踏入灵砂境，二十岁便可横扫一方。然而，林澈却是个例外。他自幼体弱，经脉如死水般冰冷，无论如何修炼，都无法点燃体内的灵力。\n\n“废物！滚出演武场！”\n\n“看看这垃圾，连灵力都无法运转，真是丢尽了我们林氏的脸面！”'),
#  Document(metadata={'start_index': 265}, page_content='“废物！滚出演武场！”\n\n“看看这垃圾，连灵力都无法运转，真是丢尽了我们林氏的脸面！”\n\n演武场上，少年跪伏在地，汗水顺着脸颊滑落。他的双手死死攥住衣角，指节发白。今日，是家族百年一次的“灵焰选拔”，所有族人都要当众展示天赋。而他，注定成为笑柄。\n\n突然，一道苍老的声音响起：“林澈，你可知为何无法凝聚灵力？”'),
#  Document(metadata={'start_index': 390}, page_content='突然，一道苍老的声音响起：“林澈，你可知为何无法凝聚灵力？”\n\n众人转头，只见家族执事长老林玄阴缓步走来。他的目光如刀，扫过林澈枯槁的脸庞，又落在他腰间那块泛着灰光的玉佩上。\n\n“回长老……弟子不知。”林澈声音沙哑。'),
#  Document(metadata={'start_index': 479}, page_content='“回长老……弟子不知。”林澈声音沙哑。\n\n林玄阴冷笑一声，抬手一挥，一股炽热的灵焰从掌心喷涌而出，瞬间将林澈笼罩。林澈浑身剧痛，仿佛有千万根钢针刺入骨髓。然而，就在他即将昏厥之际，玉佩突然发出微弱的光芒，将那股灵焰尽数吸收。\n\n“嗯？”林玄阴瞳孔骤缩。他盯着玉佩，脸色阴晴不定，“竟敢私藏‘灵焰核心’？林澈，你可知这是死罪？”\n\n全场哗然。'),
#  Document(metadata={'start_index': 644}, page_content='全场哗然。\n\n灵焰核心，乃是灵武者突破瓶颈的至宝，价值连城。而林澈，竟敢将其藏在身边？\n\n林澈抬起头，眼中满是倔强：“这块玉佩，是父亲临终前交给我的。他说……这是我林氏的耻辱。”\n\n“呵！”林玄阴冷哼一声，“林震天，你竟敢将家族至宝私藏二十年？看来，你们父子都是叛徒！”\n\n话音未落，林玄阴挥手祭出一柄灵焰长剑，剑锋直指林澈。\n\n“住手！”\n\n一道清冷的声音自天际传来。'),
#  Document(metadata={'start_index': 781}, page_content='话音未落，林玄阴挥手祭出一柄灵焰长剑，剑锋直指林澈。\n\n“住手！”\n\n一道清冷的声音自天际传来。\n\n众人仰头，只见一道白衣身影踏空而来，周身缭绕着幽蓝火焰。他的面容俊朗，眉眼间却透着凌厉之气。\n\n“灵焰宗少主，楚炎！”人群中有人惊呼。\n\n楚炎目光冰冷，落在林玄阴身上：“林执事，你可知擅动‘灵焰核心’会引来多少觊觎者？”\n\n林玄阴脸色剧变，连忙收剑，躬身行礼：“属下失礼，还请少主恕罪！”'),
#  Document(metadata={'start_index': 943}, page_content='林玄阴脸色剧变，连忙收剑，躬身行礼：“属下失礼，还请少主恕罪！”\n\n楚炎淡淡扫了林澈一眼，袖袍一挥，一道火焰没入玉佩之中。刹那间，玉佩爆发出刺目强光，化作一枚赤红晶石，悬浮在林澈掌心。\n\n“此乃‘灵焰核心’，本少主今日便收回。至于你——”楚炎指尖一点，林澈体内仿佛有一道枷锁崩裂，原本死寂的经脉竟开始涌动暖流。\n\n林澈瞪大双眼，不敢相信地握紧拳头。灵力！他竟然真的能运转灵力了！'),
#  Document(metadata={'start_index': 1100}, page_content='林澈瞪大双眼，不敢相信地握紧拳头。灵力！他竟然真的能运转灵力了！\n\n“林氏的血脉，不该埋没。”楚炎转身离去，声音飘渺如风，“记住，你不是废物，而是被命运封印的‘灵焰继承者’。”\n\n第二章：血色试炼\n\n三日后，林澈独自来到家族后山。\n\n此处名为“血灵谷”，乃林氏先祖留下的试炼之地。谷中弥漫着猩红色的雾气，内藏无数妖兽和机关，是族中天才磨砺剑术的场所。然而，林澈却站在谷口，目光平静。'),
#  Document(metadata={'start_index': 1293}, page_content='“既然命运给了我一次机会，那便还我一个答案。”他低语，踏入雾中。\n\n血灵谷内，灵气狂暴，仿佛有无形的巨兽在咆哮。林澈运转灵力，手中长剑泛起微光。他的剑法笨拙，却带着一种奇异的韵律，每一招都仿佛与天地共鸣。\n\n“叮！”\n\n一道银光骤然袭来，一只三眼妖狼扑向他。林澈身形一闪，剑锋划过妖狼咽喉。然而，妖狼竟未倒下，反而发出凄厉的嚎叫，全身化作血雾，融入雾气之中。'),
#  Document(metadata={'start_index': 1474}, page_content='“血灵谷的妖兽……竟会化血为灵？”林澈心头一震。\n\n他继续前行，雾气越来越浓，空气中弥漫着血腥味。忽然，地面塌陷，他坠入一座古老石殿。殿中，一具棺椁悬浮半空，棺盖上刻着“林震天”三个字。\n\n“父亲……”林澈喃喃。\n\n棺椁缓缓开启，一道金色符文浮现。林澈触碰符文的瞬间，脑海中涌入大量画面：'),
#  Document(metadata={'start_index': 1582}, page_content='棺椁缓缓开启，一道金色符文浮现。林澈触碰符文的瞬间，脑海中涌入大量画面：\n\n“灵焰核心，乃上古‘灵焰宗’的传承之物。你体内封印的，是‘灵焰宗’失传的‘焚天诀’。若想解开桎梏，需以血为引，以命为契，踏入‘血灵谷’最深处。”\n\n画面戛然而止。\n\n林澈抬头，棺椁中已无他人，唯有一柄通体赤红的长剑。他握住剑柄，只觉一股炽热之力涌入体内，仿佛有火山在血脉中燃烧。'),
#  Document(metadata={'start_index': 1761}, page_content='“焚天诀……”他闭上双眼，开始运转功法。\n\n刹那间，天地变色，血灵谷的雾气化作火海，林澈的身影在烈焰中若隐若现。他的剑，不再是一般灵兵，而是化作了真正的“灵焰剑”。\n\n“轰！”\n\n一道巨响震动山谷，一只由血雾凝成的九头妖兽破空而出，每一只头颅都散发着毁天灭地的威压。\n\n林澈没有畏惧，他踏着火焰，冲向妖兽。剑光如龙，灵焰如海，每一击都撕裂虚空。'),
#  Document(metadata={'start_index': 1896}, page_content='林澈没有畏惧，他踏着火焰，冲向妖兽。剑光如龙，灵焰如海，每一击都撕裂虚空。\n\n最终，妖兽的九个头颅尽数陨落，化作九道血光没入林澈体内。他的修为突飞猛进，从灵砂境一跃至灵岩境！\n\n“这只是开始。”林澈抹去嘴角血迹，望向血灵谷深处。那里，一片血色湖泊静静流淌，湖心，一座古老的祭坛若隐若现。\n\n第三章：命运的召唤\n\n血色湖泊中央，祭坛上悬浮着一块晶莹剔透的石碑。石碑上，刻着一行古篆：'),
#  Document(metadata={'start_index': 2041}, page_content='第三章：命运的召唤\n\n血色湖泊中央，祭坛上悬浮着一块晶莹剔透的石碑。石碑上，刻着一行古篆：\n\n“灵焰为引，焚尽天命。”\n\n林澈伸手触碰石碑，顿时，一股庞大的信息涌入脑海。\n\n原来，灵武大陆的灵力，并非自然孕育，而是由“灵焰宗”以焚天之力炼化的结果。而“灵焰核心”，正是连接灵焰宗与凡界的钥匙。千年前，灵焰宗因一场浩劫覆灭，核心被封印在林氏血脉中，等待有缘人开启。'),
#  Document(metadata={'start_index': 2224}, page_content='“所以，我的使命……是继承灵焰宗的遗志？”林澈喃喃。\n\n就在这时，血湖突然沸腾，一道黑影从湖底升起。那是一个身披黑袍的男子，面容被兜帽遮住，唯有眼中两点幽光闪烁。\n\n“林澈，你终于醒了。”黑影低沉的声音回荡在湖面，“我是灵焰宗的守护者，也是你父亲的挚友。如今，‘灵焰核心’即将重铸，但黑暗势力也在觊觎它。你必须在三天内离开血灵谷，否则……”\n\n话音未落，黑影突然化作灰烬消散。'),
#  Document(metadata={'start_index': 2396}, page_content='话音未落，黑影突然化作灰烬消散。\n\n林澈心头一紧，顾不得多想，抓起石碑上的“灵焰核心”，冲出血灵谷。身后，血湖翻涌，仿佛有无数妖兽在苏醒。\n\n当他踏出谷口时，天空已是一片血色。\n\n“灵武纪元，终究将迎来新的风暴。”林澈握紧长剑，望向远方。')]

# %%
# 按字符切割

from langchain_text_splitters import CharacterTextSplitter

# 读取文件
with open("novel.txt") as f:
    lingwujiyuan = f.read()

# 使用递归字符切分器
text_splitter = RecursiveCharacterTextSplitter(
    separators="。",          # 分隔符
    chunk_size=200,           # 每个块的大小
    chunk_overlap=50,         # 重叠的字符数
    length_function=len,      # 计算长度的函数
    add_start_index=True,     # 是否添加开始索引
    is_separator_regex=False,  # 是否使用正则表达式
)

text = text_splitter.create_documents([lingwujiyuan])
text
# Out:
# [Document(metadata={'start_index': 0}, page_content='《灵武纪元》\n\n第一章：废柴觉醒\n\n灵武大陆，万族林立，强者为尊。\n\n这片大陆上，灵气如海，孕育了无数修炼者。从低阶的灵砂境到巅峰的灵峰境，每一个境界都如同天堑，划分着凡人与神祇的界限。然而，在这片强者争锋的土地上，却有一个少年，被家族视为耻辱，连最基础的灵力都无法凝聚。\n\n他叫林澈，是林氏家族旁支的弃子。\n\n林氏家族，乃是北境灵武世家，以“灵焰剑道”闻名于世'),
#  Document(metadata={'start_index': 135}, page_content='。\n\n他叫林澈，是林氏家族旁支的弃子。\n\n林氏家族，乃是北境灵武世家，以“灵焰剑道”闻名于世。家族子弟天赋卓绝，十岁便能引动灵力，十五岁踏入灵砂境，二十岁便可横扫一方。然而，林澈却是个例外。他自幼体弱，经脉如死水般冰冷，无论如何修炼，都无法点燃体内的灵力。\n\n“废物！滚出演武场！”\n\n“看看这垃圾，连灵力都无法运转，真是丢尽了我们林氏的脸面！”\n\n演武场上，少年跪伏在地，汗水顺着脸颊滑落'),
#  Document(metadata={'start_index': 330}, page_content='。他的双手死死攥住衣角，指节发白。今日，是家族百年一次的“灵焰选拔”，所有族人都要当众展示天赋。而他，注定成为笑柄。\n\n突然，一道苍老的声音响起：“林澈，你可知为何无法凝聚灵力？”\n\n众人转头，只见家族执事长老林玄阴缓步走来。他的目光如刀，扫过林澈枯槁的脸庞，又落在他腰间那块泛着灰光的玉佩上。\n\n“回长老……弟子不知。”林澈声音沙哑'),
#  Document(metadata={'start_index': 476}, page_content='。\n\n“回长老……弟子不知。”林澈声音沙哑。\n\n林玄阴冷笑一声，抬手一挥，一股炽热的灵焰从掌心喷涌而出，瞬间将林澈笼罩。林澈浑身剧痛，仿佛有千万根钢针刺入骨髓。然而，就在他即将昏厥之际，玉佩突然发出微弱的光芒，将那股灵焰尽数吸收。\n\n“嗯？”林玄阴瞳孔骤缩。他盯着玉佩，脸色阴晴不定，“竟敢私藏‘灵焰核心’？林澈，你可知这是死罪？”\n\n全场哗然。\n\n灵焰核心，乃是灵武者突破瓶颈的至宝，价值连城'),
#  Document(metadata={'start_index': 648}, page_content='。\n\n灵焰核心，乃是灵武者突破瓶颈的至宝，价值连城。而林澈，竟敢将其藏在身边？\n\n林澈抬起头，眼中满是倔强：“这块玉佩，是父亲临终前交给我的。他说……这是我林氏的耻辱。”\n\n“呵！”林玄阴冷哼一声，“林震天，你竟敢将家族至宝私藏二十年？看来，你们父子都是叛徒！”\n\n话音未落，林玄阴挥手祭出一柄灵焰长剑，剑锋直指林澈。\n\n“住手！”\n\n一道清冷的声音自天际传来'),
#  Document(metadata={'start_index': 806}, page_content='。\n\n“住手！”\n\n一道清冷的声音自天际传来。\n\n众人仰头，只见一道白衣身影踏空而来，周身缭绕着幽蓝火焰。他的面容俊朗，眉眼间却透着凌厉之气。\n\n“灵焰宗少主，楚炎！”人群中有人惊呼。\n\n楚炎目光冰冷，落在林玄阴身上：“林执事，你可知擅动‘灵焰核心’会引来多少觊觎者？”\n\n林玄阴脸色剧变，连忙收剑，躬身行礼：“属下失礼，还请少主恕罪！”\n\n楚炎淡淡扫了林澈一眼，袖袍一挥，一道火焰没入玉佩之中'),
#  Document(metadata={'start_index': 1003}, page_content='。刹那间，玉佩爆发出刺目强光，化作一枚赤红晶石，悬浮在林澈掌心。\n\n“此乃‘灵焰核心’，本少主今日便收回。至于你——”楚炎指尖一点，林澈体内仿佛有一道枷锁崩裂，原本死寂的经脉竟开始涌动暖流。\n\n林澈瞪大双眼，不敢相信地握紧拳头。灵力！他竟然真的能运转灵力了！\n\n“林氏的血脉，不该埋没。”楚炎转身离去，声音飘渺如风，“记住，你不是废物，而是被命运封印的‘灵焰继承者’'),
#  Document(metadata={'start_index': 1145}, page_content='。”楚炎转身离去，声音飘渺如风，“记住，你不是废物，而是被命运封印的‘灵焰继承者’。”\n\n第二章：血色试炼\n\n三日后，林澈独自来到家族后山。\n\n此处名为“血灵谷”，乃林氏先祖留下的试炼之地。谷中弥漫着猩红色的雾气，内藏无数妖兽和机关，是族中天才磨砺剑术的场所。然而，林澈却站在谷口，目光平静。\n\n“既然命运给了我一次机会，那便还我一个答案。”他低语，踏入雾中'),
#  Document(metadata={'start_index': 1274}, page_content='。然而，林澈却站在谷口，目光平静。\n\n“既然命运给了我一次机会，那便还我一个答案。”他低语，踏入雾中。\n\n血灵谷内，灵气狂暴，仿佛有无形的巨兽在咆哮。林澈运转灵力，手中长剑泛起微光。他的剑法笨拙，却带着一种奇异的韵律，每一招都仿佛与天地共鸣。\n\n“叮！”\n\n一道银光骤然袭来，一只三眼妖狼扑向他。林澈身形一闪，剑锋划过妖狼咽喉。然而，妖狼竟未倒下，反而发出凄厉的嚎叫，全身化作血雾，融入雾气之中'),
#  Document(metadata={'start_index': 1421}, page_content='。林澈身形一闪，剑锋划过妖狼咽喉。然而，妖狼竟未倒下，反而发出凄厉的嚎叫，全身化作血雾，融入雾气之中。\n\n“血灵谷的妖兽……竟会化血为灵？”林澈心头一震。\n\n他继续前行，雾气越来越浓，空气中弥漫着血腥味。忽然，地面塌陷，他坠入一座古老石殿。殿中，一具棺椁悬浮半空，棺盖上刻着“林震天”三个字。\n\n“父亲……”林澈喃喃。\n\n棺椁缓缓开启，一道金色符文浮现'),
#  Document(metadata={'start_index': 1566}, page_content='。\n\n“父亲……”林澈喃喃。\n\n棺椁缓缓开启，一道金色符文浮现。林澈触碰符文的瞬间，脑海中涌入大量画面：\n\n“灵焰核心，乃上古‘灵焰宗’的传承之物。你体内封印的，是‘灵焰宗’失传的‘焚天诀’。若想解开桎梏，需以血为引，以命为契，踏入‘血灵谷’最深处。”\n\n画面戛然而止。\n\n林澈抬头，棺椁中已无他人，唯有一柄通体赤红的长剑。他握住剑柄，只觉一股炽热之力涌入体内，仿佛有火山在血脉中燃烧'),
#  Document(metadata={'start_index': 1727}, page_content='。他握住剑柄，只觉一股炽热之力涌入体内，仿佛有火山在血脉中燃烧。\n\n“焚天诀……”他闭上双眼，开始运转功法。\n\n刹那间，天地变色，血灵谷的雾气化作火海，林澈的身影在烈焰中若隐若现。他的剑，不再是一般灵兵，而是化作了真正的“灵焰剑”。\n\n“轰！”\n\n一道巨响震动山谷，一只由血雾凝成的九头妖兽破空而出，每一只头颅都散发着毁天灭地的威压。\n\n林澈没有畏惧，他踏着火焰，冲向妖兽'),
#  Document(metadata={'start_index': 1893}, page_content='。\n\n林澈没有畏惧，他踏着火焰，冲向妖兽。剑光如龙，灵焰如海，每一击都撕裂虚空。\n\n最终，妖兽的九个头颅尽数陨落，化作九道血光没入林澈体内。他的修为突飞猛进，从灵砂境一跃至灵岩境！\n\n“这只是开始。”林澈抹去嘴角血迹，望向血灵谷深处。那里，一片血色湖泊静静流淌，湖心，一座古老的祭坛若隐若现。\n\n第三章：命运的召唤\n\n血色湖泊中央，祭坛上悬浮着一块晶莹剔透的石碑'),
#  Document(metadata={'start_index': 2038}, page_content='。\n\n第三章：命运的召唤\n\n血色湖泊中央，祭坛上悬浮着一块晶莹剔透的石碑。石碑上，刻着一行古篆：\n\n“灵焰为引，焚尽天命。”\n\n林澈伸手触碰石碑，顿时，一股庞大的信息涌入脑海。\n\n原来，灵武大陆的灵力，并非自然孕育，而是由“灵焰宗”以焚天之力炼化的结果。而“灵焰核心”，正是连接灵焰宗与凡界的钥匙。千年前，灵焰宗因一场浩劫覆灭，核心被封印在林氏血脉中，等待有缘人开启'),
#  Document(metadata={'start_index': 2186}, page_content='。千年前，灵焰宗因一场浩劫覆灭，核心被封印在林氏血脉中，等待有缘人开启。\n\n“所以，我的使命……是继承灵焰宗的遗志？”林澈喃喃。\n\n就在这时，血湖突然沸腾，一道黑影从湖底升起。那是一个身披黑袍的男子，面容被兜帽遮住，唯有眼中两点幽光闪烁。\n\n“林澈，你终于醒了。”黑影低沉的声音回荡在湖面，“我是灵焰宗的守护者，也是你父亲的挚友。如今，‘灵焰核心’即将重铸，但黑暗势力也在觊觎它'),
#  Document(metadata={'start_index': 2350}, page_content='。如今，‘灵焰核心’即将重铸，但黑暗势力也在觊觎它。你必须在三天内离开血灵谷，否则……”\n\n话音未落，黑影突然化作灰烬消散。\n\n林澈心头一紧，顾不得多想，抓起石碑上的“灵焰核心”，冲出血灵谷。身后，血湖翻涌，仿佛有无数妖兽在苏醒。\n\n当他踏出谷口时，天空已是一片血色。\n\n“灵武纪元，终究将迎来新的风暴。”林澈握紧长剑，望向远方。')]

# %%
# 代码文档切割

from langchain_text_splitters import RecursiveCharacterTextSplitter, Language

# 支持解析的编程语言有：[e.value for e in Language]

PYTHON_CODE = """
def hello_world():
    print("Hello, world!")
hello_world()
"""

py_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON,
    chunk_size=50,
    chunk_overlap=10,
)

py_docs = py_splitter.create_documents([PYTHON_CODE])

py_docs
# Out:
# [Document(metadata={}, page_content='def hello_world():\n    print("Hello, world!")'),
#  Document(metadata={}, page_content='hello_world()')]

# %%
# 按token切割

from langchain_text_splitters import RecursiveCharacterTextSplitter

# 读取文件
with open("novel.txt") as f:
    lingwujiyuan = f.read()

# 使用递归字符切分器
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=200,          # 每个块的大小
    chunk_overlap=50,        # 重叠的字符数
)

text = text_splitter.create_documents([lingwujiyuan])
text
# Out:
# [Document(metadata={}, page_content='《灵武纪元》\n\n第一章：废柴觉醒\n\n灵武大陆，万族林立，强者为尊。'),
#  Document(metadata={}, page_content='这片大陆上，灵气如海，孕育了无数修炼者。从低阶的灵砂境到巅峰的灵峰境，每一个境界都如同天堑，划分着凡人与神祇的界限。然而，在这片强者争锋的土地上，却有一个少年，被家族视为耻辱，连最基'),
#  Document(metadata={}, page_content='的土地上，却有一个少年，被家族视为耻辱，连最基础的灵力都无法凝聚。'),
#  Document(metadata={}, page_content='他叫林澈，是林氏家族旁支的弃子。'),
#  Document(metadata={}, page_content='林氏家族，乃是北境灵武世家，以“灵焰剑道”闻名于世。家族子弟天赋卓绝，十岁便能引动灵力，十五岁踏入灵砂境，二十岁便可横扫一方。然而，林澈却是个例外。他自幼体弱，经脉如死水般冰冷，'),
#  Document(metadata={}, page_content='澈却是个例外。他自幼体弱，经脉如死水般冰冷，无论如何修炼，都无法点燃体内的灵力。'),
#  Document(metadata={}, page_content='“废物！滚出演武场！”\n\n“看看这垃圾，连灵力都无法运转，真是丢尽了我们林氏的脸面！”'),
#  Document(metadata={}, page_content='演武场上，少年跪伏在地，汗水顺着脸颊滑落。他的双手死死攥住衣角，指节发白。今日，是家族百年一次的“灵焰选拔”，所有族人都要当众展示天赋。而他，注定成为笑柄。'),
#  Document(metadata={}, page_content='突然，一道苍老的声音响起：“林澈，你可知为何无法凝聚灵力？”\n\n众人转头，只见家族执事长老林玄阴缓步走来。他的目光如刀，扫过林澈枯槁的脸庞，又落在他腰间那块泛着灰光的玉佩上。'),
#  Document(metadata={}, page_content='“回长老……弟子不知。”林澈声音沙哑。'),
#  Document(metadata={}, page_content='林玄阴冷笑一声，抬手一挥，一股炽热的灵焰从掌心喷涌而出，瞬间将林澈笼罩。林澈浑身剧痛，仿佛有千万根钢针刺入骨髓。然而，就在他即将昏厥之际，玉佩突然发出微弱的光芒，将那股灵焰'),
#  Document(metadata={}, page_content='将昏厥之际，玉佩突然发出微弱的光芒，将那股灵焰尽数吸收。'),
#  Document(metadata={}, page_content='“嗯？”林玄阴瞳孔骤缩。他盯着玉佩，脸色阴晴不定，“竟敢私藏‘灵焰核心’？林澈，你可知这是死罪？”\n\n全场哗然。'),
#  Document(metadata={}, page_content='全场哗然。\n\n灵焰核心，乃是灵武者突破瓶颈的至宝，价值连城。而林澈，竟敢将其藏在身边？\n\n林澈抬起头，眼中满是倔强：“这块玉佩，是父亲临终前交给我的。他说……这是我林氏的耻辱。”'),
#  Document(metadata={}, page_content='“呵！”林玄阴冷哼一声，“林震天，你竟敢将家族至宝私藏二十年？看来，你们父子都是叛徒！”\n\n话音未落，林玄阴挥手祭出一柄灵焰长剑，剑锋直指林澈。\n\n“住手！”'),
#  Document(metadata={}, page_content='“住手！”\n\n一道清冷的声音自天际传来。\n\n众人仰头，只见一道白衣身影踏空而来，周身缭绕着幽蓝火焰。他的面容俊朗，眉眼间却透着凌厉之气。\n\n“灵焰宗少主，楚炎！”人群中有人惊呼。'),
#  Document(metadata={}, page_content='“灵焰宗少主，楚炎！”人群中有人惊呼。\n\n楚炎目光冰冷，落在林玄阴身上：“林执事，你可知擅动‘灵焰核心’会引来多少觊觎者？”'),
#  Document(metadata={}, page_content='林玄阴脸色剧变，连忙收剑，躬身行礼：“属下失礼，还请少主恕罪！”'),
#  Document(metadata={}, page_content='楚炎淡淡扫了林澈一眼，袖袍一挥，一道火焰没入玉佩之中。刹那间，玉佩爆发出刺目强光，化作一枚赤红晶石，悬浮在林澈掌心。'),
#  Document(metadata={}, page_content='“此乃‘灵焰核心’，本少主今日便收回。至于你——”楚炎指尖一点，林澈体内仿佛有一道枷锁崩裂，原本死寂的经脉竟开始涌动暖流。'),
#  Document(metadata={}, page_content='林澈瞪大双眼，不敢相信地握紧拳头。灵力！他竟然真的能运转灵力了！\n\n“林氏的血脉，不该埋没。”楚炎转身离去，声音飘渺如风，“记住，你不是废物，而是被命运封印的‘灵焰继承者’。”'),
#  Document(metadata={}, page_content='第二章：血色试炼\n\n三日后，林澈独自来到家族后山。'),
#  Document(metadata={}, page_content='三日后，林澈独自来到家族后山。\n\n此处名为“血灵谷”，乃林氏先祖留下的试炼之地。谷中弥漫着猩红色的雾气，内藏无数妖兽和机关，是族中天才磨砺剑术的场所。然而，林澈却站在谷口，目光平静。'),
#  Document(metadata={}, page_content='“既然命运给了我一次机会，那便还我一个答案。”他低语，踏入雾中。'),
#  Document(metadata={}, page_content='血灵谷内，灵气狂暴，仿佛有无形的巨兽在咆哮。林澈运转灵力，手中长剑泛起微光。他的剑法笨拙，却带着一种奇异的韵律，每一招都仿佛与天地共鸣。\n\n“叮！”'),
#  Document(metadata={}, page_content='“叮！”\n\n一道银光骤然袭来，一只三眼妖狼扑向他。林澈身形一闪，剑锋划过妖狼咽喉。然而，妖狼竟未倒下，反而发出凄厉的嚎叫，全身化作血雾，融入雾气之中。'),
#  Document(metadata={}, page_content='“血灵谷的妖兽……竟会化血为灵？”林澈心头一震。'),
#  Document(metadata={}, page_content='他继续前行，雾气越来越浓，空气中弥漫着血腥味。忽然，地面塌陷，他坠入一座古老石殿。殿中，一具棺椁悬浮半空，棺盖上刻着“林震天”三个字。\n\n“父亲……”林澈喃喃。'),
#  Document(metadata={}, page_content='“父亲……”林澈喃喃。\n\n棺椁缓缓开启，一道金色符文浮现。林澈触碰符文的瞬间，脑海中涌入大量画面：'),
#  Document(metadata={}, page_content='“灵焰核心，乃上古‘灵焰宗’的传承之物。你体内封印的，是‘灵焰宗’失传的‘焚天诀’。若想解开桎梏，需以血为引，以命为契，踏入‘血灵谷’最深处。”\n\n画面戛然而止。'),
#  Document(metadata={}, page_content='画面戛然而止。\n\n林澈抬头，棺椁中已无他人，唯有一柄通体赤红的长剑。他握住剑柄，只觉一股炽热之力涌入体内，仿佛有火山在血脉中燃烧。\n\n“焚天诀……”他闭上双眼，开始运转功法。'),
#  Document(metadata={}, page_content='“焚天诀……”他闭上双眼，开始运转功法。\n\n刹那间，天地变色，血灵谷的雾气化作火海，林澈的身影在烈焰中若隐若现。他的剑，不再是一般灵兵，而是化作了真正的“灵焰剑”。\n\n“轰！”'),
#  Document(metadata={}, page_content='“轰！”\n\n一道巨响震动山谷，一只由血雾凝成的九头妖兽破空而出，每一只头颅都散发着毁天灭地的威压。\n\n林澈没有畏惧，他踏着火焰，冲向妖兽。剑光如龙，灵焰如海，每一击都撕裂虚空。'),
#  Document(metadata={}, page_content='最终，妖兽的九个头颅尽数陨落，化作九道血光没入林澈体内。他的修为突飞猛进，从灵砂境一跃至灵岩境！'),
#  Document(metadata={}, page_content='“这只是开始。”林澈抹去嘴角血迹，望向血灵谷深处。那里，一片血色湖泊静静流淌，湖心，一座古老的祭坛若隐若现。\n\n第三章：命运的召唤'),
#  Document(metadata={}, page_content='第三章：命运的召唤\n\n血色湖泊中央，祭坛上悬浮着一块晶莹剔透的石碑。石碑上，刻着一行古篆：\n\n“灵焰为引，焚尽天命。”\n\n林澈伸手触碰石碑，顿时，一股庞大的信息涌入脑海。'),
#  Document(metadata={}, page_content='原来，灵武大陆的灵力，并非自然孕育，而是由“灵焰宗”以焚天之力炼化的结果。而“灵焰核心”，正是连接灵焰宗与凡界的钥匙。千年前，灵焰宗因一场浩劫覆灭，核心被封印在林氏血脉中，等待有缘人开'),
#  Document(metadata={}, page_content='劫覆灭，核心被封印在林氏血脉中，等待有缘人开启。'),
#  Document(metadata={}, page_content='“所以，我的使命……是继承灵焰宗的遗志？”林澈喃喃。\n\n就在这时，血湖突然沸腾，一道黑影从湖底升起。那是一个身披黑袍的男子，面容被兜帽遮住，唯有眼中两点幽光闪烁。'),
#  Document(metadata={}, page_content='“林澈，你终于醒了。”黑影低沉的声音回荡在湖面，“我是灵焰宗的守护者，也是你父亲的挚友。如今，‘灵焰核心’即将重铸，但黑暗势力也在觊觎它。你必须在三天内离开血灵谷，否则……”'),
#  Document(metadata={}, page_content='话音未落，黑影突然化作灰烬消散。\n\n林澈心头一紧，顾不得多想，抓起石碑上的“灵焰核心”，冲出血灵谷。身后，血湖翻涌，仿佛有无数妖兽在苏醒。\n\n当他踏出谷口时，天空已是一片血色。'),
#  Document(metadata={}, page_content='当他踏出谷口时，天空已是一片血色。\n\n“灵武纪元，终究将迎来新的风暴。”林澈握紧长剑，望向远方。')]

# %%
# 按token切割   另一种方法

from langchain_text_splitters import TokenTextSplitter

# 读取文件
with open("novel.txt") as f:
    lingwujiyuan = f.read()

# 使用 TokenTextSplitter 分割文本
text_splitter = TokenTextSplitter(
    chunk_size=200,          # 每个块的 token 数量
    chunk_overlap=50,        # 重叠的 token 数量
    encoding_name="cl100k_base"  # 指定编码方式（与 tiktoken 兼容）
)

# 将文本分割为块并转换为 Document 对象
texts = text_splitter.create_documents([lingwujiyuan])
texts
# Out:
# [Document(metadata={}, page_content='《灵武纪元》\n\n第一章：废柴觉醒\n\n灵武大陆，万族林立，强者为尊。\n\n这片大陆上，灵气如海，孕育了无数修炼者。从低阶的灵砂境到巅峰的灵峰境，每一个境界都如同天堑，划分着凡人与神祇的界限。然而，在这片强者争锋的土地上，却有一个少年，被家族视为耻辱，连最基础的灵力都无法凝聚。\n\n他叫林澈，是林氏家族旁支的�'),
#  Document(metadata={}, page_content='，被家族视为耻辱，连最基础的灵力都无法凝聚。\n\n他叫林澈，是林氏家族旁支的弃子。\n\n林氏家族，乃是北境灵武世家，以“灵焰剑道”闻名于世。家族子弟天赋卓绝，十岁便能引动灵力，十五岁踏入灵砂境，二十岁便可横扫一方。然而，林澈却是个例外。他自幼体弱，经脉如死水般冰冷，无论如何修炼，都无法点燃体内'),
#  Document(metadata={}, page_content='��却是个例外。他自幼体弱，经脉如死水般冰冷，无论如何修炼，都无法点燃体内的灵力。\n\n“废物！滚出演武场！”\n\n“看看这垃圾，连灵力都无法运转，真是丢尽了我们林氏的脸面！”\n\n演武场上，少年跪伏在地，汗水顺着脸颊滑落。他的双手死死攥住衣角，指节发白。今日，是家族百年一次的“灵焰选拔”，所有族人都要当众展示天赋。而'),
#  Document(metadata={}, page_content='�攥住衣角，指节发白。今日，是家族百年一次的“灵焰选拔”，所有族人都要当众展示天赋。而他，注定成为笑柄。\n\n突然，一道苍老的声音响起：“林澈，你可知为何无法凝聚灵力？”\n\n众人转头，只见家族执事长老林玄阴缓步走来。他的目光如刀，扫过林澈枯槁的脸庞，又落在他腰间那块泛着灰光的玉佩上。\n\n“回长老……弟子不知。”林澈'),
#  Document(metadata={}, page_content='��庞，又落在他腰间那块泛着灰光的玉佩上。\n\n“回长老……弟子不知。”林澈声音沙哑。\n\n林玄阴冷笑一声，抬手一挥，一股炽热的灵焰从掌心喷涌而出，瞬间将林澈笼罩。林澈浑身剧痛，仿佛有千万根钢针刺入骨髓。然而，就在他即将昏厥之际，玉佩突然发出微弱的光芒，将那股灵焰尽数�'),
#  Document(metadata={}, page_content='髓。然而，就在他即将昏厥之际，玉佩突然发出微弱的光芒，将那股灵焰尽数吸收。\n\n“嗯？”林玄阴瞳孔骤缩。他盯着玉佩，脸色阴晴不定，“竟敢私藏‘灵焰核心’？林澈，你可知这是死罪？”\n\n全场哗然。\n\n灵焰核心，乃是灵武者突破瓶颈的至宝，价值连城。而林澈，竟敢将其藏在身边？\n\n林澈抬起头，眼'),
#  Document(metadata={}, page_content='�破瓶颈的至宝，价值连城。而林澈，竟敢将其藏在身边？\n\n林澈抬起头，眼中满是倔强：“这块玉佩，是父亲临终前交给我的。他说……这是我林氏的耻辱。”\n\n“呵！”林玄阴冷哼一声，“林震天，你竟敢将家族至宝私藏二十年？看来，你们父子都是叛徒！”\n\n话音未落，林玄阴挥手祭出一柄灵焰长剑，剑锋直指林澈。\n\n“住手！”\n\n'),
#  Document(metadata={}, page_content='�！”\n\n话音未落，林玄阴挥手祭出一柄灵焰长剑，剑锋直指林澈。\n\n“住手！”\n\n一道清冷的声音自天际传来。\n\n众人仰头，只见一道白衣身影踏空而来，周身缭绕着幽蓝火焰。他的面容俊朗，眉眼间却透着凌厉之气。\n\n“灵焰宗少主，楚炎！”人群中有人惊呼。\n\n楚炎目光冰冷，落在林玄阴身上：“林执事，你可知擅动‘'),
#  Document(metadata={}, page_content='人群中有人惊呼。\n\n楚炎目光冰冷，落在林玄阴身上：“林执事，你可知擅动‘灵焰核心’会引来多少觊觎者？”\n\n林玄阴脸色剧变，连忙收剑，躬身行礼：“属下失礼，还请少主恕罪！”\n\n楚炎淡淡扫了林澈一眼，袖袍一挥，一道火焰没入玉佩之中。刹那间，玉佩爆发出刺目强光，化作一枚赤红晶石，悬浮在�'),
#  Document(metadata={}, page_content='入玉佩之中。刹那间，玉佩爆发出刺目强光，化作一枚赤红晶石，悬浮在林澈掌心。\n\n“此乃‘灵焰核心’，本少主今日便收回。至于你——”楚炎指尖一点，林澈体内仿佛有一道枷锁崩裂，原本死寂的经脉竟开始涌动暖流。\n\n林澈瞪大双眼，不敢相信地握紧拳头。灵力！他竟然真的能运转灵力了！\n\n“林氏的血脉，'),
#  Document(metadata={}, page_content='大双眼，不敢相信地握紧拳头。灵力！他竟然真的能运转灵力了！\n\n“林氏的血脉，不该埋没。”楚炎转身离去，声音飘渺如风，“记住，你不是废物，而是被命运封印的‘灵焰继承者’。”\n\n第二章：血色试炼\n\n三日后，林澈独自来到家族后山。\n\n此处名为“血灵谷”，乃林氏先祖留下的试炼之地。谷中弥漫着猩红色的雾气，内藏无数'),
#  Document(metadata={}, page_content='灵谷”，乃林氏先祖留下的试炼之地。谷中弥漫着猩红色的雾气，内藏无数妖兽和机关，是族中天才磨砺剑术的场所。然而，林澈却站在谷口，目光平静。\n\n“既然命运给了我一次机会，那便还我一个答案。”他低语，踏入雾中。\n\n血灵谷内，灵气狂暴，仿佛有无形的巨兽在咆哮。林澈运转灵力，手中长剑泛起微光。'),
#  Document(metadata={}, page_content='气狂暴，仿佛有无形的巨兽在咆哮。林澈运转灵力，手中长剑泛起微光。他的剑法笨拙，却带着一种奇异的韵律，每一招都仿佛与天地共鸣。\n\n“叮！”\n\n一道银光骤然袭来，一只三眼妖狼扑向他。林澈身形一闪，剑锋划过妖狼咽喉。然而，妖狼竟未倒下，反而发出凄厉的嚎叫，全身化作血雾，'),
#  Document(metadata={}, page_content='�狼咽喉。然而，妖狼竟未倒下，反而发出凄厉的嚎叫，全身化作血雾，融入雾气之中。\n\n“血灵谷的妖兽……竟会化血为灵？”林澈心头一震。\n\n他继续前行，雾气越来越浓，空气中弥漫着血腥味。忽然，地面塌陷，他坠入一座古老石殿。殿中，一具棺椁悬浮半空，棺盖上刻着“林震天”三个字。\n\n“'),
#  Document(metadata={}, page_content='座古老石殿。殿中，一具棺椁悬浮半空，棺盖上刻着“林震天”三个字。\n\n“父亲……”林澈喃喃。\n\n棺椁缓缓开启，一道金色符文浮现。林澈触碰符文的瞬间，脑海中涌入大量画面：\n\n“灵焰核心，乃上古‘灵焰宗’的传承之物。你体内封印的，是‘灵焰宗’失传的‘焚天诀’。若想解开桎梏，需以血为引，以命为契，'),
#  Document(metadata={}, page_content='�印的，是‘灵焰宗’失传的‘焚天诀’。若想解开桎梏，需以血为引，以命为契，踏入‘血灵谷’最深处。”\n\n画面戛然而止。\n\n林澈抬头，棺椁中已无他人，唯有一柄通体赤红的长剑。他握住剑柄，只觉一股炽热之力涌入体内，仿佛有火山在血脉中燃烧。\n\n“焚天诀……”他闭上双眼，开始运转功法。\n\n刹那间，天地变色，血灵'),
#  Document(metadata={}, page_content='血脉中燃烧。\n\n“焚天诀……”他闭上双眼，开始运转功法。\n\n刹那间，天地变色，血灵谷的雾气化作火海，林澈的身影在烈焰中若隐若现。他的剑，不再是一般灵兵，而是化作了真正的“灵焰剑”。\n\n“轰！”\n\n一道巨响震动山谷，一只由血雾凝成的九头妖兽破空而出，每一只头颅都散发着毁天灭地的威压。\n\n林澈没有畏惧，他�'),
#  Document(metadata={}, page_content='��兽破空而出，每一只头颅都散发着毁天灭地的威压。\n\n林澈没有畏惧，他踏着火焰，冲向妖兽。剑光如龙，灵焰如海，每一击都撕裂虚空。\n\n最终，妖兽的九个头颅尽数陨落，化作九道血光没入林澈体内。他的修为突飞猛进，从灵砂境一跃至灵岩境！\n\n“这只是开始。”林澈抹去嘴角血迹，望向血灵谷�'),
#  Document(metadata={}, page_content='�砂境一跃至灵岩境！\n\n“这只是开始。”林澈抹去嘴角血迹，望向血灵谷深处。那里，一片血色湖泊静静流淌，湖心，一座古老的祭坛若隐若现。\n\n第三章：命运的召唤\n\n血色湖泊中央，祭坛上悬浮着一块晶莹剔透的石碑。石碑上，刻着一行古篆：\n\n“灵焰为引，焚尽天命。”\n\n林澈伸手触碰石碑，顿'),
#  Document(metadata={}, page_content='��碑上，刻着一行古篆：\n\n“灵焰为引，焚尽天命。”\n\n林澈伸手触碰石碑，顿时，一股庞大的信息涌入脑海。\n\n原来，灵武大陆的灵力，并非自然孕育，而是由“灵焰宗”以焚天之力炼化的结果。而“灵焰核心”，正是连接灵焰宗与凡界的钥匙。千年前，灵焰宗因一场浩劫覆灭，核心被封印在林氏血脉中，等待有缘人开启。\n\n“所以，我的使'),
#  Document(metadata={}, page_content='�宗因一场浩劫覆灭，核心被封印在林氏血脉中，等待有缘人开启。\n\n“所以，我的使命……是继承灵焰宗的遗志？”林澈喃喃。\n\n就在这时，血湖突然沸腾，一道黑影从湖底升起。那是一个身披黑袍的男子，面容被兜帽遮住，唯有眼中两点幽光闪烁。\n\n“林澈，你终于醒了。”黑影低沉的声音回荡在湖面，“我是灵焰宗的守护者'),
#  Document(metadata={}, page_content='烁。\n\n“林澈，你终于醒了。”黑影低沉的声音回荡在湖面，“我是灵焰宗的守护者，也是你父亲的挚友。如今，‘灵焰核心’即将重铸，但黑暗势力也在觊觎它。你必须在三天内离开血灵谷，否则……”\n\n话音未落，黑影突然化作灰烬消散。\n\n林澈心头一紧，顾不得多想，抓起石碑上的“灵焰核心”，冲出血灵谷。身后，血湖翻涌，�'),
#  Document(metadata={}, page_content='，顾不得多想，抓起石碑上的“灵焰核心”，冲出血灵谷。身后，血湖翻涌，仿佛有无数妖兽在苏醒。\n\n当他踏出谷口时，天空已是一片血色。\n\n“灵武纪元，终究将迎来新的风暴。”林澈握紧长剑，望向远方。')]
